# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# <h1><center>The Perceptron</center></h1>

# %% [markdown]
# ### Autor
# - Nombre: Edwin Jahir Rueda Rojas
# - email: ejrueda95g@gmail.com

# %% [markdown]
# ### Redes Neuronales Artificiales (ANN)
#
# - Las redes neronales artificiales son un tipo de algoritmos bioinspirados los cuales ayudan a resolver problemas en diferentes campos. Este tipo de algorimos asemejan el funcionamiento de las neuronas humanas, las cuales forman una estructura compleja en base a conexiones de unidades básicas (neuronas) llamadas aquí de perceptrones.

# %%
Image.open("../images/neurona_perceptron.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=886x258 at 0x7F1054B32AC8>

# %% [markdown]
# - En comparación, las variables $x_1,x_2,\dots, x_n$ en el perceptron, representan las entradas a las dendritas en la neurona biológica. A su vez, el núcleo biológico es representado por una función de activación.
# - La salida representada por $y$ (perceptron) representa la salida de la neurona biológica la cual es un impulso que se desplaza por el Axón si dicha neurona está exitada.

# %% [markdown]
# ### Perceptron
#
# - La unidad básica, es la representación de una neurona biológica

# %%
Image.open("../images/perceptron.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=466x291 at 0x7F102E0F64E0>

# %% [markdown]
# - donde $x_1,\dots,x_n$ representa el vector de caracteristicas de entrada y el <b>bias</b> representa una constante de entrada.
# - $w_0,\dots,w_n$ representan los pesos del perceptron, los cuales mediante un algoritmo de aprendizaje serán ajustados para obtener el menor error posible.
# - $h$ es la función de salida antes de pasar por la función de activación. Esta viene dada por:
# $$ h =  w_1x_1 + w_2x_2 + \dots + w_nx_n + w_0$$

# %% [markdown]
# Note que $h$ puede representarse como una multiplicación vectorial:
# $$ h = w^Tx$$
# donde el vector $w = [w_0,w_1,\dots,w_n]$ y el vector $x = [1,x_1,\dots,x_n]$

# %% [markdown]
# Finalmente, la función de activación normalmente empleada para problemas de clasificación binária (perceptron exitado o no), es la función sigmoide:
# $$ \sigma(u) = \frac{1}{1 + e^{-u}}$$

# %%
u = np.linspace(-10, 10, 1000)
sigmoide = 1/(1+np.exp(-u))
plt.grid()
plt.title("función sigmoide")
plt.xlabel("u")
plt.ylabel("sigmoide(u)")
plt.plot(u, sigmoide);

# %% [markdown]
# ### Función de costo y entrenamiendo del Perceptron

# %% [markdown]
# Normalmente, en un dataset de entrenamiento se cuentan con pares de ejemplos de entrenamiento $(x, y)$, donde $x$ representan el ejemplo de entrada y $y$ representa el objetivo (target), siendo que para problemas de clasificación binaria, $y=1$ o $y=0$.

# %% [markdown]
# Suponga que estamos trabajando con un problema de clasificación binaria. Para poder penalizar nuestro perceptron (si clasifica bien o mal), tendremos que definir una función de costo, la cual es denotada por:
# $$J({\bf{w}})=-\frac{1}{m}\sum_{j=1}^{m} \hat{y}\log(\sigma({\bf{w}}^T{\bf{x}}_j)) + (1-\hat{y})\log(1-\sigma({\bf{w}}^T{\bf{x}}_j))$$
# $$J({\bf{w}})=-\frac{1}{m}\sum_{j=1}^{m} \hat{y}\log(\sigma(h)) + (1-\hat{y})\log(1-\sigma(h))$$

# %% [markdown]
# Donde $m$ representa el número de ejemplos de entrenamiento y $\hat{y}$ representa la clase predicha por el Perceptron.

# %% [markdown]
# Para entrenar el Perceptron se recurre al algoritmo del descenso del gradiente (<b>Gradient Descent</b>), el cual se basa en una regla iterativa para actualizar los pesos del Perceptron:
# $${\bf{w}}(\tau) = {\bf{w}}(\tau-1) - \alpha\nabla J({\bf{w}})$$
#
# $$w_i(\tau) = w_i(\tau-1) - \frac{\alpha}{m}\sum_{j=1}^{m} (\sigma({\bf{w}}^T{\bf{x}}_j) - \hat{y})x_{ji}$$

# %% [markdown]
# donde $\alpha$ representa la taza de aprendizaje, $x_{ji}$ es la $i$-th variable de entrada de el $j$-th ejemplo de entrenamiento.

# %%
class perceptron:
    
    def __init__(self):
        """
        inicializar variables
        """
        self.error = []
        self.accuracy = []
    
    def sigmoide(self, u):
        """
        Computa la fución sigmoide
        """
        return 1/(1+np.exp(-u))

    def entrenar(self, X, y, lr=.001, iterations=10000):
        """
        Entrena el perceptron
        """
        m = X.shape[0]
        #se concatena el bias para cada ejemplo de entrenamiento
        X_train = np.concatenate((X, np.ones((X.shape[0],1))), axis=1)
        #se inicializan los pesos
        #w = np.array([30,-40,-120])
        self.w = np.random.normal(size=X_train.shape[1])
        #entrenamiento
        for i in range(iterations):
            #forward
            h = np.dot(X_train, self.w)
            y_hat = self.sigmoide(h.T)
            output_error = y_hat - y
            self.error.append(np.sum(abs(output_error))/m)
            #accuracy
            y_predict = (y_hat>.5)*1
            self.accuracy.append(np.mean(y_predict==y))
            #backward
            temp = np.dot(X_train.T, output_error.T)
            w_new = self.w - lr*temp/m
            self.w = w_new
        return self.w, self.error, self.accuracy
    
    def predecir(self, X):
        X_ = np.concatenate((X, np.ones((X.shape[0],1))), axis=1)
        h = np.dot(X_, self.w)
        return self.sigmoide(h)

# %% [markdown]
# ### Probando nuestro Perceptron
#
# - Para probar nuestro Perceptron utilizamos el conocido "iris dataset", solo que tomaremos unicamente dos de sus tres clases.
# - Este dataset cuentra con tres clases, cada una con 50 ejemplos que representan metadatos de 3 flores diferentes.
# - por cuestiones de aprendizaje únicamente tomamos 2 metadatos.

# %%
from sklearn import datasets
#Cargamos el dataset
iris = datasets.load_iris()
X, y = iris.data, iris.target
#tomamos unicamente las dos primeras clases (100 ejemplos) y los dos primeros metadatos (columnas)
X_train = X[:100][:,:2]
y_train = y[:100]
fig, ax = plt.subplots(1,1)
ax.scatter(X_train[:,0], X_train[:,1], c=y_train, cmap="Set2");

# %%
#iniciamos la clase
p = perceptron()
w, error, accu = p.entrenar(X_train, y_train, lr=0.01, iterations=10000)

# %%
plt.figure(figsize=(8,4))
plt.ylabel("eror")
plt.plot(error, label="error");
plt.plot(accu, label="Accuracy", color="orange");
plt.grid()
plt.xlabel("iteraciones");
plt.legend();

# %% [markdown]
# ### Frontera de decisión construída por el Perceptron

# %%
print("pesos aprendidos:", w)
x1 = np.linspace(4,7,100)
#ecuación de la línea (ver Anexos al final del notebook)
x2 = -(w[0]/w[1])*x1 - w[2]/w[1]
plt.grid()
plt.scatter(X_train[:,0], X_train[:,1], c=y_train, cmap="Set2")
plt.plot(x1, x2, label="frontera", color="black");
plt.legend();
# Out:
# pesos aprendidos: [ 3.23972067 -4.85990332 -2.48769355]

# %%
predict = (p.predecir(X_train) > 0.5)*1
print("precisión del perceptron:", sum(predict==y_train), "%")
# Out:
# precisión del perceptron: 99 %

# %% [markdown]
# ### Conclusiones
# - Note que un perceptron solo puede generar fronteras lineales.
# - La inicialización de los pesos ayuda mucho para que el error pueda disminuir (perceptron converge)

# %% [markdown]
# ### Perceptron con Tensorflow

# %%
import tensorflow as tf

#creamos el perceptron
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(units=1, input_shape=(X_train.shape[1],), activation="sigmoid"))
model.compile(optimizer=tf.keras.optimizers.SGD(lr=0.01), loss="binary_crossentropy", metrics=["accuracy"])
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 1)                 3
# =================================================================
# Total params: 3
# Trainable params: 3
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist = model.fit(X_train, y_train, batch_size=32, epochs=120) #batch_size=32
# Out:
# Epoch 1/120
# 4/4 [==============================] - 0s 1ms/step - loss: 1.3584 - accuracy: 0.5000
# Epoch 2/120
# 4/4 [==============================] - 0s 1ms/step - loss: 1.0839 - accuracy: 0.5000
# Epoch 3/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.8798 - accuracy: 0.5000
# Epoch 4/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.7491 - accuracy: 0.5000
# Epoch 5/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.6760 - accuracy: 0.5000
# Epoch 6/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.6338 - accuracy: 0.5000
# Epoch 7/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.6154 - accuracy: 0.5500
# Epoch 8/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.6102 - accuracy: 0.9500
# Epoch 9/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.6092 - accuracy: 0.7200
# Epoch 10/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.6060 - accuracy: 0.8600
# Epoch 11/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.6060 - accuracy: 0.8500
# Epoch 12/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.6010 - accuracy: 0.9700
# Epoch 13/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5993 - accuracy: 0.9900
# Epoch 14/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5972 - accuracy: 0.9700
# Epoch 15/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5977 - accuracy: 0.9900
# Epoch 16/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5947 - accuracy: 0.9500
# Epoch 17/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5929 - accuracy: 0.9700
# Epoch 18/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5915 - accuracy: 0.9600
# Epoch 19/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5878 - accuracy: 0.9300
# Epoch 20/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5852 - accuracy: 0.9700
# Epoch 21/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5842 - accuracy: 0.9900
# Epoch 22/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5814 - accuracy: 0.9500
# Epoch 23/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5801 - accuracy: 0.9900
# Epoch 24/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5779 - accuracy: 0.9700
# Epoch 25/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5760 - accuracy: 0.9900
# Epoch 26/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5733 - accuracy: 0.9900
# Epoch 27/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5729 - accuracy: 0.9900
# Epoch 28/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5704 - accuracy: 0.9800
# Epoch 29/120
# 4/4 [==============================] - 0s 923us/step - loss: 0.5676 - accuracy: 0.9700
# Epoch 30/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5660 - accuracy: 0.9900
# Epoch 31/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5671 - accuracy: 0.9600
# Epoch 32/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5655 - accuracy: 0.9400
# Epoch 33/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5616 - accuracy: 0.9800
# Epoch 34/120
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5594 - accuracy: 0.9900
# Epoch 35/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5565 - accuracy: 0.9900
# Epoch 36/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5548 - accuracy: 0.9900
# Epoch 37/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5536 - accuracy: 0.9900
# Epoch 38/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5509 - accuracy: 0.9900
# Epoch 39/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5514 - accuracy: 0.9200
# Epoch 40/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5491 - accuracy: 0.9600
# Epoch 41/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5459 - accuracy: 0.9700
# Epoch 42/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5435 - accuracy: 0.9900
# Epoch 43/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5445 - accuracy: 0.9800
# Epoch 44/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5444 - accuracy: 0.8800
# Epoch 45/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5429 - accuracy: 0.8600
# Epoch 46/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5370 - accuracy: 0.9800
# Epoch 47/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5368 - accuracy: 0.9400
# Epoch 48/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5335 - accuracy: 0.9900
# Epoch 49/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5317 - accuracy: 0.9900
# Epoch 50/120
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5302 - accuracy: 0.9900
# Epoch 51/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5289 - accuracy: 0.9900
# Epoch 52/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5270 - accuracy: 0.9800
# Epoch 53/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5267 - accuracy: 0.9500
# Epoch 54/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5235 - accuracy: 0.9900
# Epoch 55/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5225 - accuracy: 0.9700
# Epoch 56/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5220 - accuracy: 0.9800
# Epoch 57/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5187 - accuracy: 0.9900
# Epoch 58/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5177 - accuracy: 0.9700
# Epoch 59/120
# 4/4 [==============================] - 0s 955us/step - loss: 0.5161 - accuracy: 0.9700
# Epoch 60/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5139 - accuracy: 0.9900
# Epoch 61/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5128 - accuracy: 0.9800
# Epoch 62/120
# 4/4 [==============================] - 0s 977us/step - loss: 0.5104 - accuracy: 0.9900
# Epoch 63/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5099 - accuracy: 0.9900
# Epoch 64/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5078 - accuracy: 0.9900
# Epoch 65/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5065 - accuracy: 0.9900
# Epoch 66/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5050 - accuracy: 0.9900
# Epoch 67/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5039 - accuracy: 0.9900
# Epoch 68/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5023 - accuracy: 0.9900
# Epoch 69/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5030 - accuracy: 0.9900
# Epoch 70/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4995 - accuracy: 0.9900
# Epoch 71/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4991 - accuracy: 0.9700
# Epoch 72/120
# 4/4 [==============================] - 0s 951us/step - loss: 0.4963 - accuracy: 0.9900
# Epoch 73/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4947 - accuracy: 0.9900
# Epoch 74/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4931 - accuracy: 0.9900
# Epoch 75/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4916 - accuracy: 0.9900
# Epoch 76/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4916 - accuracy: 0.9800
# Epoch 77/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4923 - accuracy: 0.9700
# Epoch 78/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4913 - accuracy: 0.9700
# Epoch 79/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4891 - accuracy: 0.9700
# Epoch 80/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4888 - accuracy: 0.9600
# Epoch 81/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4852 - accuracy: 0.9900
# Epoch 82/120
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4849 - accuracy: 0.9700
# Epoch 83/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4835 - accuracy: 0.9700
# Epoch 84/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4811 - accuracy: 0.9700
# Epoch 85/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4789 - accuracy: 0.9900
# Epoch 86/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4768 - accuracy: 0.9900
# Epoch 87/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4762 - accuracy: 0.9900
# Epoch 88/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4755 - accuracy: 0.9900
# Epoch 89/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4739 - accuracy: 0.9900
# Epoch 90/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4718 - accuracy: 0.9900
# Epoch 91/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4716 - accuracy: 0.9900
# Epoch 92/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4690 - accuracy: 0.9900
# Epoch 93/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4684 - accuracy: 0.9900
# Epoch 94/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4685 - accuracy: 0.9800
# Epoch 95/120
# 4/4 [==============================] - 0s 974us/step - loss: 0.4676 - accuracy: 0.9800
# Epoch 96/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4674 - accuracy: 0.9900
# Epoch 97/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4647 - accuracy: 0.9800
# Epoch 98/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4642 - accuracy: 0.9800
# Epoch 99/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4617 - accuracy: 0.9900
# Epoch 100/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4598 - accuracy: 0.9900
# Epoch 101/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4593 - accuracy: 0.9700
# Epoch 102/120
# 4/4 [==============================] - 0s 979us/step - loss: 0.4574 - accuracy: 0.9800
# Epoch 103/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4564 - accuracy: 0.9900
# Epoch 104/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4545 - accuracy: 0.9900
# Epoch 105/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4551 - accuracy: 0.9900
# Epoch 106/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4525 - accuracy: 0.9900
# Epoch 107/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4516 - accuracy: 0.9900
# Epoch 108/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4510 - accuracy: 0.9900
# Epoch 109/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4490 - accuracy: 0.9900
# Epoch 110/120
# 4/4 [==============================] - 0s 994us/step - loss: 0.4484 - accuracy: 0.9900
# Epoch 111/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4462 - accuracy: 0.9900
# Epoch 112/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4458 - accuracy: 0.9900
# Epoch 113/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4441 - accuracy: 0.9900
# Epoch 114/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4436 - accuracy: 0.9900
# Epoch 115/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4432 - accuracy: 0.9900
# Epoch 116/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4425 - accuracy: 0.9800
# Epoch 117/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4399 - accuracy: 0.9900
# Epoch 118/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4390 - accuracy: 0.9900
# Epoch 119/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4377 - accuracy: 0.9900
# Epoch 120/120
# 4/4 [==============================] - 0s 962us/step - loss: 0.4375 - accuracy: 0.9900

# %%
plt.figure(figsize=(10,3))
#Error
plt.subplot(1,2,1)
plt.ylabel("eror")
plt.plot(hist.epoch, hist.history["loss"], label="error");
plt.grid()
plt.legend()
plt.xlabel("epochs");
#Accuracy
plt.subplot(1,2,2)
plt.ylabel("Accuracy")
plt.grid()
plt.plot(hist.epoch, hist.history["accuracy"], label="Accuracy", color="orange");
plt.legend()
plt.xlabel("epochs");

# %% [markdown]
# #### Frontera de decisión

# %%
w_tf = model.get_weights()
w1 = w_tf[0][0]
w2 = w_tf[0][1]
w0 = w_tf[1][0]

print("pesos aprendidos:", w1, w2, w0)
x1 = np.linspace(4,7,100)
#ecuación de la línea (ver notas al final)
x2 = -(w1/w2)*x1 - w0/w2   #x2 = -(w[0]/w[1])*x1 - w[2]/w[1]
plt.grid()
plt.scatter(X_train[:,0], X_train[:,1], c=y_train, cmap="Set2")
plt.plot(x1, x2, label="frontera", color="black");
plt.legend();
# Out:
# pesos aprendidos: [0.63124454] [-1.0421649] -0.14490697

# %% [markdown]
# ### Perceptron multicapa

# %%
print("Perceptron multicapa = Red Neuronal")
Image.open("../images/multilayer_perceptron.png")
# Out:
# Perceptron multicapa = Red Neuronal
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=415x286 at 0x7F0FAC274E48>

# %% [markdown]
# ### Funciones de activación mas comunes

# %%
u = np.linspace(-8,8,100)
g = (np.exp(u) - np.exp(-u))/(np.exp(u) + np.exp(-u))
plt.figure(figsize=(10,6))
plt.subplot(2,2,1)
plt.plot(u,g)
plt.title("tanh")
plt.grid();

plt.subplot(2,2,2)
sigmoide = 1/(1+np.exp(-u))
plt.grid()
plt.title("función sigmoid")
plt.plot(u, sigmoide);

plt.subplot(2,2,3)
plt.grid()
plt.title("lineal")
plt.plot(u, u);

plt.subplot(2,2,4)
plt.grid()
plt.title("ReLu")
vals = tf.keras.activations.relu(u,alpha=.2)
plt.plot(u, vals);

# %% [markdown]
# ## Anexos

# %% [markdown]
# - Explicación de como pintar la frontera de decisión para un perceptron con 2 entradas ($x_1, x_2$)

# %% [markdown]
# $$ h = w_1x_1 + w_2x_2 + w_0 $$

# %% [markdown]
# hacemos cambio de variables ($x = x1, y = x2, b = w_0$)
# $$ h = w_1x + w_2y + b $$

# %% [markdown]
# Note que si igualamos a cero la función $h$ obtenemos la ecuación general de la recta recta ($Ax + By + C = 0$).
#
# Buscamos los interceptos:
#
# - Intercepto en $y~(x=0)$:
# $$ w_2y + b = 0$$
# $$ y = \frac{-b}{w_2} $$
#
# - Intercepto en $x~(y=0)$:
# $$ w_1x + b = 0 $$
# $$ x = \frac{-b}{w_1} $$

# %% [markdown]
# - Note que tenemos dos puntos en el plano 2D: $(0, -b/w_2)$ y $(-b/w_1, 0)$, con lo cual podemos calcular la pendiente de la recta:
#
# $$ m = \frac{y_2-y_1}{x_2-x_1} $$

# %% [markdown]
# $$ m = \frac{ 0 - (-b/w_2)}{-b/w_1 - 0} $$

# %% [markdown]
# $$ m = -\frac{w_1}{w_2} $$

# %% [markdown]
# - con la pendiente calculada ya podemos calcular la función de la recta empleando la eciación general de la recta $y = mx + c$, donde $c=-b/w_2$

# %% [markdown]
# - Por lo tanto la función que representa la frontera de decisión es igual a:
# $$ y = -\frac{w_1}{w_2}x -\frac{b}{w_2} $$
