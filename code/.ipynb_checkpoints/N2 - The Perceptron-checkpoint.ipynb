# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# <h1><center>The Perceptron</center></h1>

# %% [markdown]
# ### Autor
# - Nombre: Edwin Jahir Rueda Rojas
# - email: ejrueda95g@gmail.com

# %% [markdown]
# ### Redes Neuronales Artificiales (ANN)
#
# - Las redes neronales artificiales son un tipo de algoritmos bioinspirados los cuales ayudan a resolver problemas en diferentes campos. Este tipo de algorimos asemejan el funcionamiento de las neuronas humanas, las cuales forman una estructura compleja en base a conexiones de unidades básicas (neuronas) llamadas aquí de perceptrones.

# %%
Image.open("../images/neurona_perceptron.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=886x258 at 0x7FE4EEECCC50>

# %% [markdown]
# - En comparación, las variables $x_1,x_2,\dots, x_n$ en el perceptron, representan las entradas a las dendritas en la neurona biológica. A su vez, el núcleo biológico es representado por una función de activación.
# - La salida representada por $y$ (perceptron) representa la salida de la neurona biológica la cual es un impulso que se desplaza por el Axón si dicha neurona está exitada.

# %% [markdown]
# ### Perceptron
#
# - La unidad básica, es la representación de una neurona biológica

# %%
Image.open("../images/perceptron.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=466x291 at 0x7FE4EEF7C7B8>

# %% [markdown]
# - donde $x_1,\dots,x_n$ representa el vector de caracteristicas de entrada y el <b>bias</b> representa una constante de entrada.
# - $w_0,\dots,w_n$ representan los pesos del perceptron, los cuales mediante un algoritmo de aprendizaje serán ajustados para obtener el menor error posible.
# - $h$ es la función de salida antes de pasar por la función de activación. Esta viene dada por:
# $$ h =  w_1x_1 + w_2x_2 + \dots + w_nx_n + w_0$$

# %% [markdown]
# Note que $h$ puede representarse como una multiplicación vectorial:
# $$ h = w^Tx$$
# donde el vector $w = [w_0,w_1,\dots,w_n]$ y el vector $x = [1,x_1,\dots,x_n]$

# %% [markdown]
# Finalmente, la función de activación normalmente empleada para problemas de clasificación binária (perceptron exitado o no), es la función sigmoide:
# $$ \sigma(u) = \frac{1}{1 + e^{-u}}$$

# %%
u = np.linspace(-10, 10, 1000)
sigmoide = 1/(1+np.exp(-u))
plt.grid()
plt.title("función sigmoide")
plt.xlabel("u")
plt.ylabel("sigmoide(u)")
plt.plot(u, sigmoide);

# %% [markdown]
# ### Función de costo y entrenamiendo del Perceptron

# %% [markdown]
# Normalmente, en un dataset de entrenamiento se cuentan con pares de ejemplos de entrenamiento $(x, y)$, donde $x$ representan el ejemplo de entrada y $y$ representa el objetivo (target), siendo que para problemas de clasificación binaria, $y=1$ o $y=0$.

# %% [markdown]
# Suponga que estamos trabajando con un problema de clasificación binaria. Para poder penalizar nuestro perceptron (si clasifica bien o mal), tendremos que definir una función de costo, la cual es denotada por:
# $$J({\bf{w}})=-\frac{1}{m}\sum_{j=1}^{m} \hat{y}\log(\sigma({\bf{w}}^T{\bf{x}}_j)) + (1-\hat{y})\log(1-\sigma({\bf{w}}^T{\bf{x}}_j))$$
# $$J({\bf{w}})=-\frac{1}{m}\sum_{j=1}^{m} \hat{y}\log(\sigma(h)) + (1-\hat{y})\log(1-\sigma(h))$$

# %% [markdown]
# Donde $m$ representa el número de ejemplos de entrenamiento y $\hat{y}$ representa la clase predicha por el Perceptron.

# %% [markdown]
# Para entrenar el Perceptron se recurre al algoritmo del descenso del gradiente (<b>Gradient Descent</b>), el cual se basa en una regla iterativa para actualizar los pesos del Perceptron:
# $${\bf{w}}(\tau) = {\bf{w}}(\tau-1) - \alpha\nabla J({\bf{w}})$$
#
# $$w_i(\tau) = w_i(\tau-1) - \frac{\alpha}{m}\sum_{j=1}^{m} (\sigma({\bf{w}}^T{\bf{x}}_j) - \hat{y})x_{ji}$$

# %% [markdown]
# donde $\alpha$ representa la taza de aprendizaje, $x_{ji}$ es la $i$-th variable de entrada de el $j$-th ejemplo de entrenamiento.

# %%
class perceptron:
    
    def __init__(self):
        """
        inicializar variables
        """
        self.error = []
    
    def sigmoide(self, u):
        """
        Computa la fución sigmoide
        """
        return 1/(1+np.exp(-u))

    def entrenar(self, X, y, lr=.001, iterations=10000):
        """
        Entrena el perceptron
        """
        m = X.shape[0]
        #se concatena el bias para cada ejemplo de entrenamiento
        X_train = np.concatenate((X, np.ones((X.shape[0],1))), axis=1)
        #se inicializan los pesos
        #w = np.array([30,-40,-120])
        self.w = np.random.normal(size=X_train.shape[1])
        #entrenamiento
        for i in range(iterations):
            #forward
            h = np.dot(X_train, self.w)
            y_hat = self.sigmoide(h.T)
            output_error = y_hat - y
            self.error.append(np.sum(abs(output_error))/m)
            #backward
            temp = np.dot(X_train.T, output_error.T)
            w_new = self.w - lr*temp/m
            self.w = w_new
        return self.w, self.error
    
    def predecir(self, X):
        X_ = np.concatenate((X, np.ones((X.shape[0],1))), axis=1)
        h = np.dot(X_, self.w)
        return self.sigmoide(h)

# %% [markdown]
# ### Probando nuestro Perceptron
#
# - Para probar nuestro Perceptron utilizamos el conocido "iris dataset", solo que tomaremos unicamente dos de sus tres clases.
# - Este dataset cuentra con tres clases, cada una con 50 ejemplos que representan metadatos de 3 flores diferentes.
# - por cuestiones de aprendizaje únicamente tomamos 2 metadatos.

# %%
from sklearn import datasets
#Cargamos el dataset
iris = datasets.load_iris()
X, y = iris.data, iris.target
#tomamos unicamente las dos primeras clases (100 ejemplos) y los dos primeros metadatos (columnas)
X_train = X[:100][:,:2]
y_train = y[:100]
fig, ax = plt.subplots(1,1)
ax.scatter(X_train[:,0], X_train[:,1], c=y2, cmap="Set2");

# %%
#iniciamos la clase
p = perceptron()
w, error = p.entrenar(X_train, y_train, lr=0.01, iterations=10000)

# %%
plt.grid()
plt.ylabel("error")
plt.xlabel("iteraciones")
plt.plot(error);

# %% [markdown]
# ### Frontera de decisión construída por el Perceptron

# %%
print("pesos aprendidos:", w)
x1 = np.linspace(4,7,100)
#ecuación de la línea (ver notas al final)
x2 = -(w[0]/w[1])*x1 - w[2]/w[1]
plt.grid()
plt.scatter(X_train[:,0], X_train[:,1], c=y2, cmap="Set2")
plt.plot(x1, x2, label="frontera", color="black");
plt.legend();
# Out:
# pesos aprendidos: [ 2.93473818 -5.17594767  0.12236707]

# %%
predict = (p.predecir(X_train) > 0.5)*1
print("precisión del perceptron:", sum(predict==y_train), "%")
# Out:
# precisión del perceptron: 99 %

# %% [markdown]
# ### Conclusiones
# - Note que un perceptron solo puede generar fronteras lineales.
# - La inicialización de los pesos ayuda mucho para que el error pueda disminuir (perceptron converge)

# %% [markdown]
# ### Perceptron con Tensorflow

# %%
import tensorflow as tf

#creamos el perceptron
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(units=1, input_shape=(X_train.shape[1],), activation="sigmoid"))
model.compile(optimizer=tf.keras.optimizers.SGD(lr=0.001), loss="binary_crossentropy", metrics=["accuracy"])
model.summary()
# Out:
# Model: "sequential_23"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_23 (Dense)             (None, 1)                 3
# =================================================================
# Total params: 3
# Trainable params: 3
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist = model.fit(X_train, y_train, epochs=120)
# Out:
# Epoch 1/120
# 4/4 [==============================] - 0s 2ms/step - loss: 1.1278 - accuracy: 0.5000
# Epoch 2/120
# 4/4 [==============================] - 0s 1ms/step - loss: 1.1010 - accuracy: 0.5000
# Epoch 3/120
# 4/4 [==============================] - 0s 2ms/step - loss: 1.0679 - accuracy: 0.5000
# Epoch 4/120
# 4/4 [==============================] - 0s 1ms/step - loss: 1.0449 - accuracy: 0.5000
# Epoch 5/120
# 4/4 [==============================] - 0s 1ms/step - loss: 1.0128 - accuracy: 0.5000
# Epoch 6/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.9843 - accuracy: 0.5000
# Epoch 7/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.9573 - accuracy: 0.5000
# Epoch 8/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.9290 - accuracy: 0.5000
# Epoch 9/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.9102 - accuracy: 0.5000
# Epoch 10/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.8862 - accuracy: 0.5000
# Epoch 11/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.8605 - accuracy: 0.5000
# Epoch 12/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.8342 - accuracy: 0.5000
# Epoch 13/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.8098 - accuracy: 0.5000
# Epoch 14/120
# 4/4 [==============================] - 0s 970us/step - loss: 0.7889 - accuracy: 0.5000
# Epoch 15/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.7667 - accuracy: 0.5000
# Epoch 16/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.7486 - accuracy: 0.5000
# Epoch 17/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.7326 - accuracy: 0.5000
# Epoch 18/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7159 - accuracy: 0.5000
# Epoch 19/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.7023 - accuracy: 0.5000
# Epoch 20/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.6863 - accuracy: 0.5000
# Epoch 21/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.6710 - accuracy: 0.5000
# Epoch 22/120
# 4/4 [==============================] - 0s 944us/step - loss: 0.6568 - accuracy: 0.5000
# Epoch 23/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.6411 - accuracy: 0.5100
# Epoch 24/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.6304 - accuracy: 0.5200
# Epoch 25/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.6173 - accuracy: 0.5300
# Epoch 26/120
# 4/4 [==============================] - 0s 952us/step - loss: 0.6044 - accuracy: 0.5300
# Epoch 27/120
# 4/4 [==============================] - 0s 964us/step - loss: 0.5940 - accuracy: 0.5300
# Epoch 28/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5844 - accuracy: 0.5300
# Epoch 29/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5733 - accuracy: 0.5500
# Epoch 30/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5649 - accuracy: 0.5500
# Epoch 31/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5595 - accuracy: 0.5500
# Epoch 32/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5504 - accuracy: 0.5600
# Epoch 33/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5432 - accuracy: 0.5700
# Epoch 34/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5364 - accuracy: 0.5700
# Epoch 35/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5289 - accuracy: 0.5700
# Epoch 36/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5248 - accuracy: 0.5900
# Epoch 37/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5202 - accuracy: 0.6000
# Epoch 38/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5149 - accuracy: 0.6100
# Epoch 39/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5101 - accuracy: 0.6400
# Epoch 40/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5057 - accuracy: 0.6600
# Epoch 41/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5025 - accuracy: 0.6800
# Epoch 42/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4976 - accuracy: 0.7400
# Epoch 43/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4939 - accuracy: 0.7600
# Epoch 44/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4895 - accuracy: 0.7900
# Epoch 45/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4869 - accuracy: 0.8000
# Epoch 46/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4846 - accuracy: 0.8000
# Epoch 47/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4810 - accuracy: 0.8100
# Epoch 48/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4782 - accuracy: 0.8300
# Epoch 49/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4756 - accuracy: 0.8300
# Epoch 50/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4724 - accuracy: 0.8500
# Epoch 51/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4690 - accuracy: 0.8800
# Epoch 52/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4675 - accuracy: 0.8800
# Epoch 53/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4665 - accuracy: 0.8800
# Epoch 54/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4653 - accuracy: 0.8800
# Epoch 55/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4636 - accuracy: 0.8900
# Epoch 56/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4633 - accuracy: 0.8900
# Epoch 57/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4624 - accuracy: 0.8900
# Epoch 58/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4618 - accuracy: 0.8900
# Epoch 59/120
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4606 - accuracy: 0.8900
# Epoch 60/120
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4588 - accuracy: 0.9000
# Epoch 61/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4577 - accuracy: 0.9000
# Epoch 62/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4569 - accuracy: 0.9000
# Epoch 63/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4562 - accuracy: 0.9000
# Epoch 64/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4556 - accuracy: 0.9100
# Epoch 65/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4545 - accuracy: 0.9200
# Epoch 66/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4534 - accuracy: 0.9200
# Epoch 67/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4526 - accuracy: 0.9200
# Epoch 68/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4513 - accuracy: 0.9400
# Epoch 69/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4505 - accuracy: 0.9400
# Epoch 70/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4505 - accuracy: 0.9400
# Epoch 71/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4489 - accuracy: 0.9400
# Epoch 72/120
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4480 - accuracy: 0.9600
# Epoch 73/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4470 - accuracy: 0.9600
# Epoch 74/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4465 - accuracy: 0.9600
# Epoch 75/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4464 - accuracy: 0.9600
# Epoch 76/120
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4459 - accuracy: 0.9600
# Epoch 77/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4454 - accuracy: 0.9600
# Epoch 78/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4449 - accuracy: 0.9700
# Epoch 79/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4441 - accuracy: 0.9700
# Epoch 80/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4435 - accuracy: 0.9700
# Epoch 81/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4433 - accuracy: 0.9700
# Epoch 82/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4430 - accuracy: 0.9700
# Epoch 83/120
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4425 - accuracy: 0.9700
# Epoch 84/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4420 - accuracy: 0.9700
# Epoch 85/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4419 - accuracy: 0.9700
# Epoch 86/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4418 - accuracy: 0.9700
# Epoch 87/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4417 - accuracy: 0.9700
# Epoch 88/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4412 - accuracy: 0.9800
# Epoch 89/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4411 - accuracy: 0.9800
# Epoch 90/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4406 - accuracy: 0.9800
# Epoch 91/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4406 - accuracy: 0.9800
# Epoch 92/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4402 - accuracy: 0.9800
# Epoch 93/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4400 - accuracy: 0.9800
# Epoch 94/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4399 - accuracy: 0.9800
# Epoch 95/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4397 - accuracy: 0.9800
# Epoch 96/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4399 - accuracy: 0.9800
# Epoch 97/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4395 - accuracy: 0.9800
# Epoch 98/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4395 - accuracy: 0.9800
# Epoch 99/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4390 - accuracy: 0.9800
# Epoch 100/120
# 4/4 [==============================] - 0s 989us/step - loss: 0.4388 - accuracy: 0.9800
# Epoch 101/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4388 - accuracy: 0.9800
# Epoch 102/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4388 - accuracy: 0.9800
# Epoch 103/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4388 - accuracy: 0.9800
# Epoch 104/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4386 - accuracy: 0.9800
# Epoch 105/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4384 - accuracy: 0.9800
# Epoch 106/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4381 - accuracy: 0.9800
# Epoch 107/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4379 - accuracy: 0.9800
# Epoch 108/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4376 - accuracy: 0.9900
# Epoch 109/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4373 - accuracy: 0.9900
# Epoch 110/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4373 - accuracy: 0.9900
# Epoch 111/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4371 - accuracy: 0.9900
# Epoch 112/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4370 - accuracy: 0.9900
# Epoch 113/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4369 - accuracy: 0.9900
# Epoch 114/120
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4368 - accuracy: 0.9900
# Epoch 115/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4366 - accuracy: 0.9900
# Epoch 116/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4366 - accuracy: 0.9900
# Epoch 117/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4364 - accuracy: 0.9900
# Epoch 118/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4363 - accuracy: 0.9900
# Epoch 119/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4362 - accuracy: 0.9900
# Epoch 120/120
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4360 - accuracy: 0.9900

# %%
plt.figure(figsize=(10,3))
#Error
plt.subplot(1,2,1)
plt.ylabel("eror")
plt.plot(hist.epoch, hist.history["loss"], label="error");
plt.grid()
plt.xlabel("epochs");
#Accuracy
plt.subplot(1,2,2)
plt.ylabel("Accuracy")
plt.grid()
plt.plot(hist.epoch, hist.history["accuracy"], label="error", color="green");
plt.xlabel("epochs");

# %% [markdown]
# ### Perceptron multicapa

# %%
print("Perceptron multicapa = Red Neuronal")
Image.open("../images/multilayer_perceptron.png")
# Out:
# Perceptron multicapa = Red Neuronal
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=415x286 at 0x7FE4D8977860>
