# %% [markdown]
# <h1><center>Object Recognition</center></h1>

# %% [markdown]
# ### Autor
# - Nombre: Edwin Jahir Rueda Rojas
# - email: ejrueda95g@gmail.com

# %% [markdown]
# - En este notebook se implementará un pipeline para reconocimiento de objetos en imágenes. Para ello se implementarán las redes neuronales previamente entrenadas.
#
# - El pipeline propeusto para la identificación es uno de los más simples de la literatura, el cual divide la imágen en cuadriculas de igual tamaño y predice la casa de cada cuadricula. Después, en base a un umbral de probabilidad se unen las cuadriculas para generar la zona con su respectiva clase.

# %%
from PIL import Image

# %%
Image.open("../images/object_recognition.jpg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x381 at 0x7F4DC88619A0>
